# %%
# %matplotlib inline
import pandas as pd

# %%
from IPython.core.display import HTML
css = open('style-table.css').read() + open('style-notebook.css').read()
HTML('<style>{}</style>'.format(css))
# Out:
# <style>body {
#     margin: 0;
#     font-family: Helvetica;
# }
# table.dataframe {
#     border-collapse: collapse;
#     border: none;
# }
# table.dataframe tr {
#     border: none;
# }
# table.dataframe td, table.dataframe th {
#     margin: 0;
#     border: 1px solid white;
#     padding-left: 0.25em;
#     padding-right: 0.25em;
# }
# table.dataframe th:not(:empty) {
#     background-color: #fec;
#     text-align: left;
#     font-weight: normal;
# }
# table.dataframe tr:nth-child(2) th:empty {
#     border-left: none;
#     border-right: 1px dashed #888;
# }
# table.dataframe td {
#     border: 2px solid #ccf;
#     background-color: #f4f4ff;
# }
# h3 {
#     color: white;
#     background-color: black;
#     padding: 0.5em;
# }
# </style>

# %%
titles = pd.DataFrame.from_csv('data/titles.csv', index_col=None)
titles.head()
# Out:
#              title  year
# 0         Kangkong  2001
# 1     Streer Paona  1991
# 2         Ha-Simla  1969
# 3  Soho Conspiracy  1950
# 4        Firelight  1964

# %%
cast = pd.DataFrame.from_csv('data/cast.csv', index_col=None)
cast.head()
# Out:
#                   title  year      name   type                character     n
# 0        Closet Monster  2015  Buffy #1  actor                  Buffy 4  31.0
# 1       Suuri illusioni  1985    Homo $  actor                   Guests  22.0
# 2   Battle of the Sexes  2017   $hutter  actor          Bobby Riggs Fan  10.0
# 3  Secret in Their Eyes  2015   $hutter  actor          2002 Dodger Fan   NaN
# 4            Steve Jobs  2015   $hutter  actor  1988 Opera House Patron   NaN

# %% [markdown]
# ### Using groupby(), plot the number of films that have been released each decade in the history of cinema.

# %%
c = cast
c.head()
# Out:
#                   title  year      name   type                character     n
# 0        Closet Monster  2015  Buffy #1  actor                  Buffy 4  31.0
# 1       Suuri illusioni  1985    Homo $  actor                   Guests  22.0
# 2   Battle of the Sexes  2017   $hutter  actor          Bobby Riggs Fan  10.0
# 3  Secret in Their Eyes  2015   $hutter  actor          2002 Dodger Fan   NaN
# 4            Steve Jobs  2015   $hutter  actor  1988 Opera House Patron   NaN

# %%
c.groupby(c.year // 10 * 10).size().plot(ylim=0, kind='bar')

# %% [markdown]
# ### Use groupby() to plot the number of "Hamlet" films made each decade.

# %%
c = cast
c.head()
# Out:
#                   title  year      name   type                character     n
# 0        Closet Monster  2015  Buffy #1  actor                  Buffy 4  31.0
# 1       Suuri illusioni  1985    Homo $  actor                   Guests  22.0
# 2   Battle of the Sexes  2017   $hutter  actor          Bobby Riggs Fan  10.0
# 3  Secret in Their Eyes  2015   $hutter  actor          2002 Dodger Fan   NaN
# 4            Steve Jobs  2015   $hutter  actor  1988 Opera House Patron   NaN

# %%
c[c.title == 'Hamlet'].groupby(c.year // 10 * 10).size().plot(kind='bar')

# %% [markdown]
# ### How many leading (n=1) roles were available to actors, and how many to actresses, in each year of the 1950s?

# %%
c = cast
c.head()
# Out:
#                   title  year      name   type                character     n
# 0        Closet Monster  2015  Buffy #1  actor                  Buffy 4  31.0
# 1       Suuri illusioni  1985    Homo $  actor                   Guests  22.0
# 2   Battle of the Sexes  2017   $hutter  actor          Bobby Riggs Fan  10.0
# 3  Secret in Their Eyes  2015   $hutter  actor          2002 Dodger Fan   NaN
# 4            Steve Jobs  2015   $hutter  actor  1988 Opera House Patron   NaN

# %%
a = c[c.n == 1]
a
# Out:
#                                               title  year               name  \
# 100                          Live Freaky Die Freaky  2006            Nick 13
# 136                           All Things Fall Apart  2011            50 Cent
# 142                                     Freelancers  2012            50 Cent
# 143                          Get Rich or Die Tryin'  2005            50 Cent
# 144                                             Gun  2010            50 Cent
# 152                                           Setup  2011            50 Cent
# 163                                    La hora cero  2010         Zapata 666
# 242      Mezhzvyozdnyie voyny. Sila probuzhdayetsya  2015          Sergey A.
# 243      Mezhzvyozdnyie voyny. Sila probuzhdayetsya  2015          Sergey A.
# 244                                    Mortem (III)  2016          Sergey A.
# 247                           Novyi film pro mumiyu  2017          Sergey A.
# ...

# %%
a[(a.year >= 1950) & (a.year < 1960)].groupby(['year', 'type']).size()
# Out:
# year  type
# 1950  actor      628
#       actress    285
# 1951  actor      654
#       actress    285
# 1952  actor      613
#       actress    302
# 1953  actor      661
#       actress    308
# 1954  actor      640
#       actress    309
# 1955  actor      652
#       actress    282
# 1956  actor      663
#       actress    308
# 1957  actor      740
#       actress    307
# 1958  actor      713
#       actress    297
# 1959  actor      736
#       actress    325
# dtype: int64

# %% [markdown]
# ### In the 1950s decade taken as a whole, how many total roles were available to actors, and how many to actresses, for each "n" number 1 through 5?

# %%
c = cast
c.head()
# Out:
#                   title  year      name   type                character     n
# 0        Closet Monster  2015  Buffy #1  actor                  Buffy 4  31.0
# 1       Suuri illusioni  1985    Homo $  actor                   Guests  22.0
# 2   Battle of the Sexes  2017   $hutter  actor          Bobby Riggs Fan  10.0
# 3  Secret in Their Eyes  2015   $hutter  actor          2002 Dodger Fan   NaN
# 4            Steve Jobs  2015   $hutter  actor  1988 Opera House Patron   NaN

# %%
c = c[c.year // 10 == 195]

# %%
c = c[c.n <= 5]

# %%
c.groupby(['n', 'type']).size()
# Out:
# n    type
# 1.0  actor      6700
#      actress    3008
# 2.0  actor      4628
#      actress    4613
# 3.0  actor      5646
#      actress    3190
# 4.0  actor      5662
#      actress    2866
# 5.0  actor      5674
#      actress    2567
# dtype: int64

# %% [markdown]
# ### Use groupby() to determine how many roles are listed for each of the Pink Panther movies.

# %%
c = cast
c.head()
# Out:
#                   title  year      name   type                character     n
# 0        Closet Monster  2015  Buffy #1  actor                  Buffy 4  31.0
# 1       Suuri illusioni  1985    Homo $  actor                   Guests  22.0
# 2   Battle of the Sexes  2017   $hutter  actor          Bobby Riggs Fan  10.0
# 3  Secret in Their Eyes  2015   $hutter  actor          2002 Dodger Fan   NaN
# 4            Steve Jobs  2015   $hutter  actor  1988 Opera House Patron   NaN

# %%
c = c[c.title == 'The Pink Panther']

# %%
c = c.sort_values(by='n')

# %%
c.groupby(['year'])[['n']].max()
# Out:
#             n
# year
# 1894      NaN
# 1900      NaN
# 1905      NaN
# 1906      3.0
# 1907      5.0
# 1908     31.0
# 1909      1.0
# 1910     18.0
# 1911     21.0
# 1912     22.0
# 1913     26.0
# 1914     52.0
# 1915    100.0
# 1916     49.0
# 1917     47.0
# 1918     34.0
# 1919     54.0
# 1920     27.0
# 1921     30.0
# 1922     30.0
# 1923     33.0
# 1924     40.0
# 1925     28.0
# 1926     32.0
# 1927     49.0
# 1928     51.0
# 1929     97.0
# 1930     37.0
# 1931     34.0
# 1932     47.0
# ...       ...
# 1997    255.0
# 1998    178.0
# 1999    254.0
# 2000  33613.0
# 2001    938.0
# 2002    910.0
# 2003    383.0
# 2004    234.0
# 2005    274.0
# 2006    194.0
# 2007    221.0
# 2008    327.0
# 2009    270.0
# 2010    294.0
# 2011    999.0
# 2012    701.0
# 2013    336.0
# 2014    587.0
# 2015    483.0
# 2016    911.0
# 2017    999.0
# 2018    115.0
# 2019     32.0
# 2020      9.0
# 2021      NaN
# 2022      NaN
# 2023      NaN
# 2024      NaN
# 2025      NaN
# 2115      NaN
# ...

# %%
c[c.title == 'The Pink Panther'].groupby(['year', ]).size()
# Out:
# character
# Agent 006                     1
# Agent Corbeille               1
# Agent Savard                  1
# Airline Pilot                 1
# Angela Dunning                1
# Arab                          1
# Aristotle Sarajos             1
# Artoff                        1
# Ballroom Reporter             1
# Bizu                          1
# Black Market Jeweler          1
# Blackjack Dealer              1
# Casino Dealer                 1
# Casino Waitress               1
# Cherie                        1
# Chinese Footballer            2
# Chinese Woman                 1
# Clouseau                      1
# Croupier                      1
# Dancer                        2
# Dealer                        1
# Defence Barrister             1
# Deputy Chief Renard           1
# Dialect Instructor            1
# Dr. Pang                      1
# Dreyfus                       1
# Escort                        1
# Eurotrash                     1
# Extra in Chinese Press Box    1
# ...

# %% [markdown]
# ### List, in order by year, each of the films in which Frank Oz has played more than 1 role.

# %% [markdown]
# ### List each of the characters that Frank Oz has portrayed at least twice.
